# %% [markdown]
# Технология блокчейн, устройство сети Bitcoin. Распределенная виртуальная машина, устройство сети
# Ethereum. Смарт-контракты, средства разработки, синтаксис языка Solidity Распределенные финансы:
# устройство распределенных бирж, сервисов кредитования, деривативных протоколов.
# DeFiLLama, CoinGecko, Binance, The Graph.
#
# Задание: сделать исследование DeFi протокола с помощью рассмотренных на лекции аналитических инструментов.
#
# Требуется:
# - Выбрать DeFi протокол из списка https://defillama.com/, допустимы топ 50 протоколов по показателю TVL (нужно выбрать протокол, который имеет собственный токен).
# - Воспользоваться сервисами Defillama, Coingecko, TheGraph, Dune analytics для сбора данных, описывающих работу протокола (некоторые примеры: TVL, Volumes, Supply/Borrow, Fees и другие). Необходимо самостоятельно сформулировать, какие данные видятся необходимыми для описания работы выбранного протокола, найти их с помощью аналитического инструмента.
# - Визуализировать собранные данные с использованием таблиц и графиков, прокомментировать полученные результаты, сделать выводы относительно характеристик работы выбранного протокола, ключевых событий, связанных с данным протоколом.
# - Отдельно рассмотреть свойства токена выбранного протокола (основные инструменты - Coingecko, Dune anayltics, Binance API). Необходимо рассмотреть временной ряд цен токена, показатели Funding fees, Volumes, Total supply и другие показатели, доступные для изучения.

# %% [markdown]
# Задание: разработать и протестировать стратегию активного предоставления ликвидностью в пуле на Uniswap V3 с хеджированием позиции.
#
# Обязательно нужно описать текстом логику придуманной стратегии: как производится выбор диапазона цен, ребалансировка, хеджирование, почему выбран именно такой пул (в соответсвии с пунктами ниже).
#
# 1. Необходимо доработать метод оценки накопленных комиссий. Далее нужно взять пул Ethereum WETH-USDC 0.05% из семинара с инструментом хеджирования Binance. Провести бектест стратегии на истории последних 2 лет и сделать выводы.
#
# 2. Также нужно доработать метод оценки накопленных комиссий. В этом пункте нужно самостоятельно выбрать пул, инструмент хеджирования и обосновать этот выбор. Провести бектест и подбор оптимальных параметров для стратегии на исторических данных.
#
# 3. К пункту 2 добавляем симуляцию Монте-Карло при выборе параметров, чтобы оценить работу стратегии не только на одной траектории цены. Так же требуется сделать сценарное моделирование: как стратегия работает на росте, падении и флэте.
